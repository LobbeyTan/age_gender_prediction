# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("preprocessed_data.csv")

# %%
df.shape
# Out:
# (47167, 3)

# %% [markdown]
# ### Randomly Plot Images

# %%
from random import randint

for _ in range(10):
    i = randint(0, df.shape[0])
    
    img = plt.imread(f"./wiki/{df['image_path'][i]}")
    print(f"path: ./wiki/{df['image_path'][i]} | size: {img.size}")
    print(f"Age: {df['age'][i]} | Gender: {df['gender'][i]}")
    
    plt.figure(i)
    plt.imshow(img)
    plt.axis("off")
    plt.plot()
    plt.show()
# Out:
# path: ./wiki/91/21040391_1987-10-08_2014.jpg | size: 684000
# Age: 4 | Gender: 1.0
# path: ./wiki/42/1890442_1975-03-29_2010.jpg | size: 941850
# Age: 4 | Gender: 1.0
# path: ./wiki/40/1265340_1945-06-03_2001.jpg | size: 360000
# Age: 6 | Gender: 1.0
# path: ./wiki/12/4629012_1987-12-19_2015.jpg | size: 917400
# Age: 4 | Gender: 1.0
# path: ./wiki/59/8913959_1989-07-07_2011.jpg | size: 384120
# Age: 3 | Gender: 1.0
# path: ./wiki/62/39382462_1889-06-26_1942.jpg | size: 357570
# Age: 6 | Gender: 1.0
# path: ./wiki/16/7716_1923-07-02_1955.jpg | size: 148392
# Age: 4 | Gender: 1.0
# path: ./wiki/51/31730751_1981-09-25_2014.jpg | size: 386760
# Age: 4 | Gender: 1.0
# path: ./wiki/50/20027350_1990-06-17_2014.jpg | size: 1156500
# Age: 3 | Gender: 1.0
# path: ./wiki/38/3512938_1943-10-05_2009.jpg | size: 872520
# Age: 7 | Gender: 1.0

# %% [markdown]
# ### Males vs Females

# %%
plt.bar(x=["female", "male"], height=[(df['gender'] == 0).sum(), (df['gender'] == 1).sum()],  color=["blue", "red"])
plt.show()

# %% [markdown]
# ### Age Frequency Count

# %%
plt.hist(df['age'], bins=10)
plt.show()
